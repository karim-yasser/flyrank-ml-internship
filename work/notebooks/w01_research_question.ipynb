# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/karim-yasser/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/karim-yasser/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 129 (delta 42), reused 92 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (129/129), 1.85 MiB | 5.40 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# /content/flyrank-ml-internship/flyrank-ml-internship

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.shape)
# Out:
# (30000, 44)

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
## My Lane

#I chose **Lane 2: Refresh / Content Opportunity Scoring**.

#My goal is to identify which pages should be prioritized for content refresh or improvement. Instead of refreshing every page, this project aims to rank pages that are most likely to benefit from optimization based on safe search and content signals.

#I selected this lane because it addresses a practical SEO decision, produces actionable recommendations, and can be implemented using interpretable machine learning models.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
## Research Question

### Decision
#Which pages should be reviewed first for content refresh?

### Action
#SEO specialists can update content, improve titles and metadata, expand articles, or monitor important pages.

### Cost of a Wrong Recommendation
#A wrong recommendation could waste time and resources by prioritizing pages that do not actually need improvement, while missing pages that deserve attention.

### Why ML Helps
#Machine learning can combine multiple performance signals and rank pages more consistently than relying on a single metric.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick look at the data
#
# The starter dataset contains **30,000** content pages and **44** features.
#
# The average search volume is **158.88**, the average competition score is **0.15**, and the average CPC is **0.49**.
#
# These values suggest that the dataset contains a wide range of SEO characteristics, making it suitable for analyzing content performance and building a decision-support model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Rows:", len(df))
print("Columns:", len(df.columns))

print("Average search volume:", round(df["search_volume"].mean(), 2))
print("Average competition:", round(df["competition"].mean(), 2))
print("Average CPC:", round(df["cpc"].mean(), 2))

print(df["content_type"].value_counts().head())
# Out:
# Rows: 30000
# Columns: 44
# Average search volume: 158.88
# Average competition: 0.15
# Average CPC: 0.49
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### Careful words
#
# This analysis is observational and based on the anonymized starter dataset.
#
# The results show patterns and relationships in the data, but they do not prove causation or explain how search engines rank pages.
#
# The model is intended to support content decisions and identify potential opportunities, not to predict Google's algorithm or guarantee performance improvements.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
